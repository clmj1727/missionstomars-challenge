# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

#optional delay for loading the page
browser.is_element_present_by_css('div.list_text', wait_time=1)
# Out:
# False

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
weather_soup = soup(html, 'html.parser')

print(weather_soup.prettify)
# Out:
# <bound method Tag.prettify of <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="description"/>
# <title>Mars Temperature Data</title>
# <link href="css/bootstrap.min.5.2.2.css" rel="stylesheet" type="text/css"/>
# <link href="css/temp.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <main>
# <div class="container py-4">
# <header class="pb-3 mb-4 border-bottom">
# <a class="d-flex align-items-center text-dark text-decoration-none" href="/">
# <span class="fs-4">Mission To Mars</span>
# </a>
# </header>
# <div class="p-5 mb-4 bg-light rounded-3">
# <div class="container-fluid py-5">
# <h1 class="display-5 fw-bold">Mars Temperature Data</h1>
# <p class="col-md-8 fs-4">This is Mars data.</p>
# <table class="table">
# <tbody><tr>
# <th>id</th>
# <th>terrestrial_date</th>
# <th>sol</th>
# <th>ls</th>
# <th>month</th>
# <th>min_temp</th>
# <th>pressure</th>
# </tr>
# ...

# %%
# Extract all rows of data
table_header = weather_soup.find_all('th')
print(table_header)

table_rows = weather_soup.find_all('tr',class_='data-row')
print(table_rows)
# Out:
# [<th>id</th>, <th>terrestrial_date</th>, <th>sol</th>, <th>ls</th>, <th>month</th>, <th>min_temp</th>, <th>pressure</th>]
# [<tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>, <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>, <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>, <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>, <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>, <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# <td>-78.0</td>
# <td>740.0</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create empty lists to contain the header elements 
header_elem = []

# Create a for loop to extract the header elements 
for header_element in table_header: 
    headings = header_element.text.strip()
    header_elem.append(headings)

print(header_elem)
# Out:
# ['id', 'terrestrial_date', 'sol', 'ls', 'month', 'min_temp', 'pressure']

# %%
# Create empty lists to contain the row elements 
row_elem = []

# Create a for loop to extract the header elements 
for rows in table_rows: 
    data = rows.find_all('td')
    row_data = [td.text.strip() for td in data]
    row_elem.append(row_data)

print(row_elem)
# Out:
# [['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'], ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'], ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'], ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'], ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'], ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'], ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'], ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'], ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'], ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'], ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'], ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'], ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'], ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'], ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'], ['170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'], ['171', '2012-09-04', '29', '166', '6', '-75.0', '747.0'], ['1
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
mission_to_mars_df = pd.DataFrame(row_elem, columns=header_elem)

print(mission_to_mars_df)
# Out:
#         id terrestrial_date   sol   ls month min_temp pressure
# 0        2       2012-08-16    10  155     6    -75.0    739.0
# 1       13       2012-08-17    11  156     6    -76.0    740.0
# 2       24       2012-08-18    12  156     6    -76.0    741.0
# 3       35       2012-08-19    13  157     6    -74.0    732.0
# 4       46       2012-08-20    14  157     6    -74.0    740.0
# ...    ...              ...   ...  ...   ...      ...      ...
# 1862  1889       2018-02-23  1973  133     5    -78.0    730.0
# 1863  1892       2018-02-24  1974  134     5    -77.0    729.0
# 1864  1894       2018-02-25  1975  134     5    -76.0    729.0
# 1865  1893       2018-02-26  1976  135     5    -77.0    728.0
# 1866  1895       2018-02-27  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %%
# Confirm DataFrame was created successfully
mission_to_mars_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mission_to_mars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1867 non-null   object
#  1   terrestrial_date  1867 non-null   object
#  2   sol               1867 non-null   object
#  3   ls                1867 non-null   object
#  4   month             1867 non-null   object
#  5   min_temp          1867 non-null   object
#  6   pressure          1867 non-null   object
# dtypes: object(7)
# memory usage: 102.2+ KB

# %%
# Examine data type of each column
print(mission_to_mars_df.dtypes)
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis: date -> datetime
mission_to_mars_df[['terrestrial_date']] = mission_to_mars_df[['terrestrial_date']].astype('datetime64[ns]')

# %%
print(mission_to_mars_df.dtypes)
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                         object
# ls                          object
# month                       object
# min_temp                    object
# pressure                    object
# dtype: object

# %%
mission_to_mars_df[['min_temp']] = mission_to_mars_df[['min_temp']].astype('float64')
mission_to_mars_df[['pressure']] = mission_to_mars_df[['pressure']].astype('float64')

# %%
# Confirm type changes were successful by examining data types again
print(mission_to_mars_df.dtypes)
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                         object
# ls                          object
# month                       object
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
mission_to_mars_df
# Out:
#         id terrestrial_date   sol   ls month  min_temp  pressure
# 0        2       2012-08-16    10  155     6     -75.0     739.0
# 1       13       2012-08-17    11  156     6     -76.0     740.0
# 2       24       2012-08-18    12  156     6     -76.0     741.0
# 3       35       2012-08-19    13  157     6     -74.0     732.0
# 4       46       2012-08-20    14  157     6     -74.0     740.0
# ...    ...              ...   ...  ...   ...       ...       ...
# 1862  1889       2018-02-23  1973  133     5     -78.0     730.0
# 1863  1892       2018-02-24  1974  134     5     -77.0     729.0
# 1864  1894       2018-02-25  1975  134     5     -76.0     729.0
# 1865  1893       2018-02-26  1976  135     5     -77.0     728.0
# 1866  1895       2018-02-27  1977  135     5     -77.0     727.0
#
# [1867 rows x 7 columns]

# %%
# 1. How many months are there on Mars?
grouped_months = mission_to_mars_df.groupby('month')
grouped_months['month'].count()
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: month, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
grouped_terr_date = mission_to_mars_df.groupby('terrestrial_date')
grouped_terr_date['terrestrial_date'].size()
days_data = grouped_terr_date['terrestrial_date'].size().sum()

print(f"There are {days_data} Martian days' worth of data.")
# Out:
# There are 1867 Martian days' worth of data.

# %%
# 3. What is the average low temperature by month?
grouped_months = mission_to_mars_df.groupby('month')
avg_low_temp = grouped_months['min_temp'].mean()
print(avg_low_temp)
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
avg_temp_chart = avg_low_temp.plot.bar()

# Label the y-axis 
avg_temp_chart.set_ylabel('Average Minimum Temperature (°C)')
# Out:
# Text(0, 0.5, 'Average Minimum Temperature (°C)')

# %%
# Identify the coldest and hottest months in Curiosity's location
# Sort the average temps in descending order
avg_low_temp_sorted = avg_low_temp.sort_values(ascending=True)

# Plot the sorted bar chart
avg_temp_chart = avg_low_temp_sorted.plot.bar()

# Label the y-axis 
avg_temp_chart.set_ylabel('Average Minimum Temperature (°C)')
# Out:
# Text(0, 0.5, 'Average Minimum Temperature (°C)')

# %%
# 4. Average pressure by Martian month
avg_pressure = grouped_months['pressure'].mean()
print(avg_pressure)
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
avg_pressure_chart = avg_pressure.plot.bar()

# Label the y-axis 
avg_pressure_chart.set_ylabel('Average Atmospheric Pressure')
avg_pressure_chart.set_xlabel('Month')
avg_pressure_chart.set_title('Average Atmospheric Pressure by Month')
# Out:
# Text(0.5, 1.0, 'Average Atmospheric Pressure by Month')

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
mission_to_mars_df.sort_values('sol').plot(
    x='sol',
    y='min_temp',
    xlabel='Number of terrestrial days',
    ylabel='Minimum Temperature'
)
# Out:
# <Axes: xlabel='Number of terrestrial days', ylabel='Minimum Temperature'>

# %%
sorted_sol = mission_to_mars_df.sort_values(by='sol')

plt.figure(figsize=(10, 5))
plt.plot(sorted_sol['sol'], sorted_sol['min_temp'], label='Min Temp')
plt.xlabel('Number of Terrestrial days')
plt.ylabel('Minimum Temperature')
plt.title('Minimum Temperature Over Time (by Sol)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save the figure as a PNG
plt.savefig('mars_min_temp_vs_sol.png', dpi=300)  # You can adjust dpi for resolution

# Show the plot
plt.show()

# %%
# Sort DataFrames
sorted_sol = mission_to_mars_df.sort_values('sol')
sorted_days = mission_to_mars_df.sort_values('terrestrial_date')

# Plot both
plt.figure(figsize=(10, 5))

# Plot min_temp vs. sol
plt.plot(sorted_sol['sol'], sorted_sol['min_temp'], label='Min Temp vs Sol', color='blue')

# Plot min_temp vs. terrestrial_days
plt.plot(sorted_days['terrestrial_date'], sorted_days['min_temp'], label='Min Temp vs Terrestrial Days', color='orange')

# Labels and title
plt.xlabel('Terrestrial Days / Sol')
plt.ylabel('Minimum Temperature')
plt.title('Minimum Temperature vs Sol and Terrestrial Days')

# Add legend
plt.legend()

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 12
#       9 plt.plot(sorted_sol['sol'], sorted_sol['min_temp'], label='Min Temp vs Sol', color='blue')
#      11 # Plot min_temp vs. terrestrial_days
# ---> 12 plt.plot(sorted_days['terrestrial_date'], sorted_days['min_temp'], label='Min Temp vs Terrestrial Days', color='orange')
#      14 # Labels and title
#      15 plt.xlabel('Terrestrial Days / Sol')
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
# ...

# %%
# Sort DataFrames
sorted_sol = mission_to_mars_df.sort_values('sol')
sorted_days = mission_to_mars_df.sort_values('terrestrial_date')

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(sorted_sol['sol'], sorted_sol['min_temp'], label='Min Temp vs Sol', color='blue')

# Label the axes
ax.set_xlabel('Number of Terrestrial Days')
ax.set_ylabel('Minimum Temperature')
ax.set_title('Minimum Temperature vs Terrestrial Days')

# Set x-axis ticks at 30-day intervals (adjust the range based on the actual data range)
x_ticks = range(0, sorted_sol['sol'].max(), 30)  # Generate ticks every 30 units
ax.set_xticks(x_ticks)

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 16
#      13 ax.set_title('Minimum Temperature vs Terrestrial Days')
#      15 # Set x-axis ticks at 30-day intervals (adjust the range based on the actual data range)
# ---> 16 x_ticks = range(0, sorted_sol['sol'].max(), 30)  # Generate ticks every 30 units
#      17 ax.set_xticks(x_ticks)
#      19 # Rotate the x-axis labels for better readability (optional)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
sorted_sol = mission_to_mars_df.sort_values('sol')
sorted_days = mission_to_mars_df.sort_values('terrestrial_date')


sorted_sol.plot(x='sol', y='min_temp', xlabel = 'Number of Terrestrial days', ylabel = "Minimum Temperature")
# Out:
# <Axes: xlabel='Number of Terrestrial days', ylabel='Minimum Temperature'>

# %% [markdown]
# ## Martian Year Estimation Based on Temperature Trends
#
# - A **year** is defined as the time it takes for a planet to complete one orbit around the Sun.
# - The chart above displays the number of terrestrial (Earth) days elapsed, plotted against the **minimum temperature** recorded on Mars.
#
# - Based on the **peaks and troughs** in the data, we can estimate that **Mars completes approximately 3 orbits** of the Sun within the time span shown. In other words, about **3 Martian years** are represented in the chart.
#
# - By observing the **spacing between temperature troughs**, we estimate that **one Martian year is about 625 Earth days**.

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
mission_to_mars_df.to_csv('data.csv')

# %%
browser.quit()
